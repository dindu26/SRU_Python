# %% [markdown]
# <a href="https://colab.research.google.com/github/dindu26/SRU_Python/blob/main/Lecture_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 1:

# %%
import keyword

# %%
print("All Keyword = ", keyword.kwlist)
# Out:
# All Keyword =  ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# Data Types

# %%
age = input("Enter your age:")
if int(age) >= 18 :
  print("You are an adult.")
else :
  print("You are a minor.")
# Out:
# Enter your age:18
# You are an adult.

# %%
num1 = input("Enter the first number:")
num2 = input("Enter the first number:")
add = int(num1) + int(num2)
sub = int(num1) - int(num2)
mult = int(num1) * int(num2)
div = int(num1) / int(num2)
flr = int(num1) // int(num2)
mod = int(num1) % int(num2)
expn = int(num1) ** int(num2)
print("The sum of the two numbers is:", add)
print("The substraction of the two numbers is:", sub)
print("The multiplication of the two numbers is:", mult)
print("The devision of the two numbers is:", div)
print("The floor of this two numbers:", flr)
print("The mod of two numbers:", mod)
print("The exp of two numbers:", expn)
print(type(div))
print(type(mult))
# Out:
# Enter the first number:8
# Enter the first number:3
# The sum of the two numbers is: 11
# The substraction of the two numbers is: 5
# The multiplication of the two numbers is: 24
# The devision of the two numbers is: 2.6666666666666665
# The floor of this two numbers: 2
# The mod of two numbers: 2
# The exp of two numbers: 512
# <class 'float'>
# <class 'int'>

# %%
frstname = input("Write your first name:")
lastname = input("Write your last name:")
# Out:
# Write your first name:Dibyendu
# Write your last name:Nanda

# %%
fullname = frstname +" " + lastname

# %%
print("The full name is:", fullname)
# Out:
# The full name is: Dibyendu Nanda

# %%
num1 = 10
num2 = 0
num3 = 10
str1 = "Good"
str2 = "Afternoon"

# %%
print("Status", num1==num2)
print("Status", num1==num3)
print("Status", str1==str2)
print("Status", num1 > num3)
# Out:
# Status False
# Status True
# Status False
# Status False

# %%
age = input("Enter your age:")
gndr = input("Wite your gender:")
if int(age) > 18 and gndr == "Male" :
  print("You are not allowed to enter.")
else :
  print("Welcome")
# Out:
# Enter your age:14
# Wite your gender:Male
# Welcome

# %%
# X+ = Y is same as X = X+Y
# X- = Y is same as X = X-Y
num1 = 10.0
num2 = 30.0
num1+= num2
num1-= num2
num1**=5
print("num1", num1)
# Out:
# num1 100000.0

# %%
list1 = [1,2,3,4]
2 not in list1
# Out:
# False

# %%
#in OR not in
students = ["Dindu", "Rahul", "Anand"]
call_name = input("The name of the stdudent:")
call_name in students
# Out:
# The name of the stdudent:Rakesh
# False

# %%
a=10
b=13
print(a|b)
# Out:
# 15

# %%
a = [1,2,3]
b=a
print(a is b)
print(a is not b)
print([1,2,3] is a)
# Out:
# True
# False
# False

# %%
numbr = input("Enter a number:")
if int(numbr)%2 != 0:
  print("It is odd number")
else :
  print("It is even number")
# Out:
# Enter a number:7
# It is odd number

# %%
mark = input("Enter the marks:")
if 90 < int(mark) < 100:
  print("The gread is A")
  if 95 < int(mark) < 100:
    print("Comment: Excellent")
elif 80 < int(mark) < 90:
  print("The gread is B")
elif 70 < int(mark) < 80:
  print("The gread is C")
# Out:
# Enter the marks:96
# The gread is A
# Comment: Excellent

# %%
genderlist = ["Male", "Female"]
age = input("What is your age?")
if int(age) >= 18 :
  gender = input("What is your gender?")
  if gender in genderlist :
    if gender == "Male":
      print("Go to right")
    else:
      print("Go to left")
  else :
    print("You are not allowed.")
else:
  print("You are not allowed.")
# Out:
# What is your age?76
# What is your gender?XYX
# You are not allowed.

# %%
consumer_stts_list = ["Residential", "Commercial", "Industrial"]
consumer_status = input("What is your statues? Residential/Commercial/Industrial: ")
if consumer_status in consumer_stts_list :
  print("Valid Consumer.")
  rqrd_units = input("How many units do you want?: ")
  if consumer_status == "Residential":
    bill = int(rqrd_units) * 2
  elif consumer_status == "Commercial":
    bill = int(rqrd_units) * 5
  else :
    bill = int(rqrd_units) * 10
  print("Your bill is:", bill)
else :
  print("Invalid Consumer. Please write correctly what is your status? Residential/Commercial/Industrial")
# Out:
# What is your statues? Residential/Commercial/Industrial: Industria
# Invalid Consumer. Please write correctly what is your status? Residential/Commercial/Industrial

# %% [markdown]
# Friday2407

# %%
numberlist = [7, 9, 5, 80, 34]
evnlst = list()
oddlist = list()
for nmbr in numberlist :
  if nmbr % 2 == 0 :
    evnlst.append(nmbr)
  else :
    oddlist.append(nmbr)
evnlst.sort()
oddlist.sort()
print("The even numbers are:", evnlst)
print("The odd numbers are", oddlist)
# Out:
# The even numbers are: [34, 80]
# The odd numbers are [5, 7, 9]

# %%
# Ask the user for numbers separated by spaces
user_input = input("Enter numbers separated by spaces: ")

# Convert the space-separated string into a list of integers
numberlist = [int(x) for x in user_input.split()]

evnlst = list()
oddlist = list()

for nmbr in numberlist:
    if nmbr % 2 == 0:
        evnlst.append(nmbr)
    else:
        oddlist.append(nmbr)

evnlst.sort()
oddlist.sort()

print("The even numbers are:", evnlst)
print("The odd numbers are:", oddlist)
# Out:
# Enter numbers separated by spaces: 7 6 9 67 90 3 65 8 32
# The even numbers are: [6, 8, 32, 90]
# The odd numbers are: [3, 7, 9, 65, 67]

# %%
def func(xx) :
  return xx**2
valueofxx = input("Enter the value of x:")
xx = int(valueofxx)
print(func(xx))
# Out:
# Enter the value of x:8
# 64

# %%
import numpy as np

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Learn how to use Streamlit
